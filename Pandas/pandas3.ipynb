# %% [markdown]
# Operating on Data in Pandas

# %%
"""                    Ufuncs: Index Preservation                     """
# Out:
# '                    Ufuncs: Index Preservation                     '

# %%
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 10, 4))
ser
# Out:
# 0    6
# 1    3
# 2    7
# 3    4
# dtype: int32

# %%
df = pd.DataFrame(rng.randint(0, 10, (3, 4)), 
                  columns= ["A", "B", "C", "D"])
df
# Out:
#    A  B  C  D
# 0  6  9  2  6
# 1  7  4  3  7
# 2  7  2  5  4

# %%
np.exp(ser)
# Out:
# 0     403.428793
# 1      20.085537
# 2    1096.633158
# 3      54.598150
# dtype: float64

# %%
np.sin(df * np.pi / 4)
# Out:
#           A             B         C             D
# 0 -1.000000  7.071068e-01  1.000000 -1.000000e+00
# 1 -0.707107  1.224647e-16  0.707107 -7.071068e-01
# 2 -0.707107  1.000000e+00 -0.707107  1.224647e-16

# %%
"""                         UFuncs: Index Alignment                   """
# Out:
# '                         UFuncs: Index Alignment                   '

# %%
# Index alignment in Series

# %%
area = pd.Series({'Alaska': 1723337, 'Texas': 695662,
                  'California': 423967}, name='area')

population = pd.Series({'California': 38332521, 'Texas': 26448193,
                         'New York': 19651127}, name='population')

# %%
population / area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])

A + B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value= 0)
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64

# %%
# Index alignment in DataFrame

# %%
A = pd.DataFrame(rng.randint(0, 20, (2, 2)), columns= list("AB"))
A
# Out:
#    A   B
# 0  1  11
# 1  5   1

# %%
B = pd.DataFrame(rng.randint(0, 10, (3, 3)), 
                 columns= list("BAC"))
B
# Out:
#    B  A  C
# 0  4  0  9
# 1  5  8  0
# 2  9  2  6

# %%
A + B
# Out:
#       A     B   C
# 0   1.0  15.0 NaN
# 1  13.0   6.0 NaN
# 2   NaN   NaN NaN

# %%
fill = A.stack().mean()
A.add(B, fill_value= fill)
# Out:
#       A     B     C
# 0   1.0  15.0  13.5
# 1  13.0   6.0   4.5
# 2   6.5  13.5  10.5

# %%
"""          Ufuncs: Operations Between DataFrame and Series          """
# Out:
# '          Ufuncs: Operations Between DataFrame and Series          '

# %%
A = rng.randint(10, size= (3, 4))
A
# Out:
# array([[3, 8, 2, 4],
#        [2, 6, 4, 8],
#        [6, 1, 3, 8]], dtype=int32)

# %%
A - A[0]
# Out:
# array([[ 0,  0,  0,  0],
#        [-1, -2,  2,  4],
#        [ 3, -7,  1,  4]], dtype=int32)

# %%
df = pd.DataFrame(A, columns= list("QRST"))
df - df.iloc[0]
# Out:
#    Q  R  S  T
# 0  0  0  0  0
# 1 -1 -2  2  4
# 2  3 -7  1  4

# %%
df.subtract(df["R"], axis = 0)
# Out:
#    Q  R  S  T
# 0 -5  0 -6 -4
# 1 -4  0 -2  2
# 2  5  0  2  7

# %%
halfrow = df.iloc[0, ::2]
halfrow
# Out:
# Q    3
# S    2
# Name: 0, dtype: int32

# %%
df - halfrow
# Out:
#      Q   R    S   T
# 0  0.0 NaN  0.0 NaN
# 1 -1.0 NaN  2.0 NaN
# 2  3.0 NaN  1.0 NaN

# %%
"""                         Examples                                  """
# Out:
# '                         Examples                                  '

# %%
y = pd.Series([1, 2, 3, 4])
np.exp(y)
# Out:
# 0     2.718282
# 1     7.389056
# 2    20.085537
# 3    54.598150
# dtype: float64

# %%
x = pd.Series([10, 20, 30], index= ["a","b", "c"])
y = pd.Series([10, 20, 30], index= ["b", "c", "d"])
x + y
# Out:
# a     NaN
# b    30.0
# c    50.0
# d     NaN
# dtype: float64

# %%
result_fill = x.add(y, fill_value= 0)
result_fill
# Out:
# a    10.0
# b    30.0
# c    50.0
# d    30.0
# dtype: float64

# %%
A = np.random.randint(1, 10, (3, 3))
df = pd.DataFrame(A, columns= list("ABC"))
np.sin(df)
# Out:
#           A         B         C
# 0  0.909297  0.656987  0.412118
# 1 -0.279415 -0.756802  0.989358
# 2 -0.958924  0.909297  0.989358

# %%
A = np.random.randint(1, 10, (3, 2))
df1_A = pd.DataFrame(A, columns= list("AB"))

B = np.random.randint(1, 10, (3, 2))
df2_B = pd.DataFrame(B, columns= list("BC"))

np.add(df1_A, df2_B)
# Out:
#     A   B   C
# 0 NaN   7 NaN
# 1 NaN  11 NaN
# 2 NaN   6 NaN

# %%
A = np.random.randint(1, 10, (3, 2))
df1_A = pd.DataFrame(A, columns= list("AB"))

B = np.random.randint(1, 10, (3, 2))
df2_B = pd.DataFrame(B, columns= list("BC"))

result_fill_A_B = df1_A.add(df2_B, fill_value= 1)
result_fill_A_B
# Out:
#      A   B     C
# 0  7.0  12   3.0
# 1  9.0  10  10.0
# 2  8.0  12   4.0

# %%
df_matrix = pd.DataFrame(np.random.randint(1, 10, (4, 4)), 
                         columns= list("ABCD"))
df_matrix - df.iloc[0]
# Out:
#      A    B    C   D
# 0  5.0 -2.0 -5.0 NaN
# 1  0.0 -6.0 -2.0 NaN
# 2  3.0 -6.0 -7.0 NaN
# 3  5.0 -3.0 -2.0 NaN

# %%
df_matrix.subtract(df_matrix["A"], axis = 0)
# Out:
#    A  B  C  D
# 0  0 -2 -3  2
# 1  0 -1  5 -1
# 2  0 -4 -3 -4
# 3  0 -3  0 -4

# %%
df_matrix1 = pd.DataFrame(np.random.randint(1, 10, (8, 16)), 
                         columns= list("ABCDEFGHIJKLMPQR"))
df_matrix1.iloc[:2, ::2]
# Out:
#    A  C  E  G  I  K  M  Q
# 0  9  6  9  5  2  1  1  6
# 1  8  8  8  7  7  9  5  8

# %%
df_matrix2 = pd.DataFrame(np.random.randint(1, 10, (8, 16)), 
                         columns= list("ABCDEFGHIJKLMPQR"))

df_matrix3 = pd.DataFrame(np.random.randint(1, 10, (8, 16)), 
                         columns= list("BCEFGIJLMPQRSTVW"))

np.add(df_matrix2, df_matrix3)
# Out:
#     A   B   C   D   E   F   G   H   I   J   K   L   M   P   Q   R   S   T   V  \
# 0 NaN  12   3 NaN  18   8   4 NaN  12  10 NaN  13   4   7  14  11 NaN NaN NaN
# 1 NaN  10  14 NaN  13   9   6 NaN  13  15 NaN   8   5   6  17  11 NaN NaN NaN
# 2 NaN  17  11 NaN  12  14  16 NaN   7  11 NaN   7  13  11  11  14 NaN NaN NaN
# 3 NaN  10   5 NaN   8   8   9 NaN   9   9 NaN  10   9   8   4   6 NaN NaN NaN
# 4 NaN   6   6 NaN   8  11   7 NaN   5  15 NaN  14   7  16  16  10 NaN NaN NaN
# 5 NaN  14  11 NaN   8  11  11 NaN   8  13 NaN   6   7  11  15  13 NaN NaN NaN
# 6 NaN  11  13 NaN   9  16   8 NaN   9  12 NaN  15  12  11  12   8 NaN NaN NaN
# 7 NaN   4  17 NaN  14   8   9 NaN   7   4 NaN   9   8   8  10  12 NaN NaN NaN
#
#     W
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN

# %%
df_matrix2.add(df_matrix3, fill_value= 0)
# Out:
#      A   B   C    D   E   F   G    H   I   J    K   L   M   P   Q   R    S  \
# 0  8.0  12   3  9.0  18   8   4  2.0  12  10  7.0  13   4   7  14  11  9.0
# 1  4.0  10  14  8.0  13   9   6  8.0  13  15  1.0   8   5   6  17  11  5.0
# 2  4.0  17  11  2.0  12  14  16  6.0   7  11  1.0   7  13  11  11  14  5.0
# 3  9.0  10   5  1.0   8   8   9  6.0   9   9  7.0  10   9   8   4   6  5.0
# 4  6.0   6   6  5.0   8  11   7  6.0   5  15  5.0  14   7  16  16  10  2.0
# 5  1.0  14  11  1.0   8  11  11  8.0   8  13  5.0   6   7  11  15  13  8.0
# 6  5.0  11  13  9.0   9  16   8  9.0   9  12  6.0  15  12  11  12   8  7.0
# 7  8.0   4  17  9.0  14   8   9  2.0   7   4  9.0   9   8   8  10  12  2.0
#
#      T    V    W
# 0  7.0  7.0  5.0
# 1  8.0  9.0  7.0
# 2  8.0  5.0  3.0
# 3  5.0  2.0  2.0
# 4  3.0  7.0  6.0
# 5  8.0  2.0  9.0
# 6  8.0  9.0  5.0
# 7  8.0  2.0  5.0
